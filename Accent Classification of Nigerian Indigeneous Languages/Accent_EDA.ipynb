# %%
import warnings
warnings.filterwarnings('ignore')
import librosa
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
from IPython.display import Audio
import numpy as np 
from matplotlib.pyplot import specgram
import pandas as pd
import IPython.display as ipd  # To play sound in the notebook
import os # interface with underlying OS that python is running on
import sys
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Accent = "/content/drive/My Drive/accentdata"

# %%
dir_list = os.listdir(Accent)
dir_list.sort()
dir_list
# Out:
# ['hausa1.wav',
#  'hausa10.wav',
#  'hausa11.wav',
#  'hausa12.wav',
#  'hausa13.wav',
#  'hausa14.wav',
#  'hausa15.wav',
#  'hausa16.wav',
#  'hausa17.wav',
#  'hausa18.wav',
#  'hausa19.wav',
#  'hausa2.wav',
#  'hausa20.wav',
#  'hausa21.wav',
#  'hausa22.wav',
#  'hausa23.wav',
#  'hausa24.wav',
#  'hausa25.wav',
#  'hausa26.wav',
#  'hausa27.wav',
#  'hausa28.wav',
#  'hausa29.wav',
#  'hausa3.wav',
#  'hausa30.wav',
#  'hausa31.wav',
#  'hausa32.wav',
#  'hausa33.wav',
#  'hausa34.wav',
#  'hausa35.wav',
#  'hausa36.wav',
#  'hausa37.wav',
#  'hausa38.wav',
#  'hausa39.wav',
#  'hausa4.wav',
#  'hausa40.wav',
#  'hausa41.wav',
#  'hausa42.wav',
#  'hausa43.wav',
#  'hausa44.wav',
#  'hausa45.wav',
#  'hausa46.wav',
#  'hausa5.wav',
#  'hausa6.wav',
#  'hausa7.wav',
#  'hausa8.wav',
#  'hausa9.wav',
#  'igbo1.wav',
#  'igbo10.wav',
#  'igbo100.wav',
#  'igbo101.wav',
#  'igbo102.wav',
#  'igbo103.wav',
#  'igbo104.wav',
#  'igbo105.wav',
#  'igbo106.wav',
#  'igbo107.wav',
# ...

# %%
emotion = []
path = []
for i in dir_list:
    fname = os.listdir(Accent)
    for f in fname:
        part = f.split('.')[0].split('-')
        emotion.append(part[0])
        path.append(Accent + '/' + f)

# %%
part
# Out:
# ['yoruba218']

# %%
emotion
# Out:
# ['igbo91',
#  'igbo102',
#  'yoruba250',
#  'yoruba361',
#  'yoruba98',
#  'yoruba231',
#  'yoruba78',
#  'yoruba295',
#  'yoruba481',
#  'yoruba352',
#  'yoruba367',
#  'yoruba228',
#  'hausa17',
#  'yoruba183',
#  'igbo15',
#  'yoruba155',
#  'yoruba143',
#  'yoruba111',
#  'yoruba151',
#  'yoruba288',
#  'yoruba454',
#  'yoruba81',
#  'igbo20',
#  'yoruba433',
#  'yoruba65',
#  'yoruba134',
#  'yoruba83',
#  'hausa7',
#  'hausa38',
#  'hausa19',
#  'yoruba398',
#  'yoruba393',
#  'yoruba103',
#  'yoruba159',
#  'yoruba243',
#  'yoruba108',
#  'hausa24',
#  'igbo127',
#  'yoruba53',
#  'igbo36',
#  'yoruba264',
#  'yoruba35',
#  'yoruba227',
#  'igbo125',
#  'yoruba102',
#  'yoruba166',
#  'yoruba105',
#  'yoruba140',
#  'hausa22',
#  'yoruba463',
#  'igbo88',
#  'yoruba132',
#  'yoruba235',
#  'yoruba335',
#  'yoruba107',
#  'yoruba37',
#  'yoruba80',
#  'yoruba43',
#  'yoruba319',
#  'yoruba195',
#  'yoruba350',
#  'yoruba471',
#  'igbo57',
#  'yoruba460',
#  'yoruba189',
# ...

# %%
accent_df = pd.DataFrame(emotion)

# %%
accent_df
# Out:
#                 0
# 0          igbo91
# 1         igbo102
# 2       yoruba250
# 3       yoruba361
# 4        yoruba98
# ...           ...
# 438239  yoruba363
# 438240  yoruba303
# 438241   yoruba34
# 438242     igbo12
# 438243  yoruba218
#
# [438244 rows x 1 columns]

# %%
accent_df.to_csv('/content/drive/My Drive/file1.csv')

# %%
accent_df = pd.concat([accent_df,pd.DataFrame(path, columns = ['path'])],axis=1)
accent_df
# Out:
#                 0                                              path
# 0          igbo91     /content/drive/My Drive/accentdata/igbo91.wav
# 1         igbo102    /content/drive/My Drive/accentdata/igbo102.wav
# 2       yoruba250  /content/drive/My Drive/accentdata/yoruba250.wav
# 3       yoruba361  /content/drive/My Drive/accentdata/yoruba361.wav
# 4        yoruba98   /content/drive/My Drive/accentdata/yoruba98.wav
# ...           ...                                               ...
# 438239  yoruba363  /content/drive/My Drive/accentdata/yoruba363.wav
# 438240  yoruba303  /content/drive/My Drive/accentdata/yoruba303.wav
# 438241   yoruba34   /content/drive/My Drive/accentdata/yoruba34.wav
# 438242     igbo12     /content/drive/My Drive/accentdata/igbo12.wav
# 438243  yoruba218  /content/drive/My Drive/accentdata/yoruba218.wav
#
# [438244 rows x 2 columns]

# %%
path
# Out:
# ['/content/drive/My Drive/accentdata/igbo91.wav',
#  '/content/drive/My Drive/accentdata/igbo102.wav',
#  '/content/drive/My Drive/accentdata/yoruba250.wav',
#  '/content/drive/My Drive/accentdata/yoruba361.wav',
#  '/content/drive/My Drive/accentdata/yoruba98.wav',
#  '/content/drive/My Drive/accentdata/yoruba231.wav',
#  '/content/drive/My Drive/accentdata/yoruba78.wav',
#  '/content/drive/My Drive/accentdata/yoruba295.wav',
#  '/content/drive/My Drive/accentdata/yoruba481.wav',
#  '/content/drive/My Drive/accentdata/yoruba352.wav',
#  '/content/drive/My Drive/accentdata/yoruba367.wav',
#  '/content/drive/My Drive/accentdata/yoruba228.wav',
#  '/content/drive/My Drive/accentdata/hausa17.wav',
#  '/content/drive/My Drive/accentdata/yoruba183.wav',
#  '/content/drive/My Drive/accentdata/igbo15.wav',
#  '/content/drive/My Drive/accentdata/yoruba155.wav',
#  '/content/drive/My Drive/accentdata/yoruba143.wav',
#  '/content/drive/My Drive/accentdata/yoruba111.wav',
# ...

# %%
accent_df.head(10)
# Out:
#            0                                              path
# 0     igbo91     /content/drive/My Drive/accentdata/igbo91.wav
# 1    igbo102    /content/drive/My Drive/accentdata/igbo102.wav
# 2  yoruba250  /content/drive/My Drive/accentdata/yoruba250.wav
# 3  yoruba361  /content/drive/My Drive/accentdata/yoruba361.wav
# 4   yoruba98   /content/drive/My Drive/accentdata/yoruba98.wav
# 5  yoruba231  /content/drive/My Drive/accentdata/yoruba231.wav
# 6   yoruba78   /content/drive/My Drive/accentdata/yoruba78.wav
# 7  yoruba295  /content/drive/My Drive/accentdata/yoruba295.wav
# 8  yoruba481  /content/drive/My Drive/accentdata/yoruba481.wav
# 9  yoruba352  /content/drive/My Drive/accentdata/yoruba352.wav

# %%
accent_df = accent_df.rename(columns={0: 'labels', 'path': 'path'})
accent_df
# Out:
#            labels                                              path
# 0          igbo91     /content/drive/My Drive/accentdata/igbo91.wav
# 1         igbo102    /content/drive/My Drive/accentdata/igbo102.wav
# 2       yoruba250  /content/drive/My Drive/accentdata/yoruba250.wav
# 3       yoruba361  /content/drive/My Drive/accentdata/yoruba361.wav
# 4        yoruba98   /content/drive/My Drive/accentdata/yoruba98.wav
# ...           ...                                               ...
# 438239  yoruba363  /content/drive/My Drive/accentdata/yoruba363.wav
# 438240  yoruba303  /content/drive/My Drive/accentdata/yoruba303.wav
# 438241   yoruba34   /content/drive/My Drive/accentdata/yoruba34.wav
# 438242     igbo12     /content/drive/My Drive/accentdata/igbo12.wav
# 438243  yoruba218  /content/drive/My Drive/accentdata/yoruba218.wav
#
# [438244 rows x 2 columns]

# %%
# Yoruba
fname1=Accent+"/"+ 'yoruba218.wav'
data, sr = librosa.load(fname1)
ipd.Audio(fname1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# CREATE LOG MEL SPECTROGRAM
plt.figure(figsize=(10, 5))
spectrogram = librosa.feature.melspectrogram(y=data, sr=sr, n_mels=128,fmax=8000) 
spectrogram = librosa.power_to_db(spectrogram)
librosa.display.specshow(spectrogram, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram - Yoruba')
plt.colorbar(format='%+2.0f dB');

# %%
# Igbo
fname1=Accent+"/"+ 'igbo2.wav'
data, sr = librosa.load(fname1)
ipd.Audio(fname1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# CREATE LOG MEL SPECTROGRAM
plt.figure(figsize=(10, 5))
spectrogram = librosa.feature.melspectrogram(y=data, sr=sr, n_mels=128,fmax=8000) 
spectrogram = librosa.power_to_db(spectrogram)
librosa.display.specshow(spectrogram, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram - Igbo')
plt.colorbar(format='%+2.0f dB');

# %%
# Hausa
fname1=Accent+"/"+ 'hausa2.wav'
data, sr = librosa.load(fname1)
ipd.Audio(fname1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# CREATE LOG MEL SPECTROGRAM
plt.figure(figsize=(10, 5))
spectrogram = librosa.feature.melspectrogram(y=data, sr=sr, n_mels=128,fmax=8000) 
spectrogram = librosa.power_to_db(spectrogram)
librosa.display.specshow(spectrogram, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram - Hausa')
plt.colorbar(format='%+2.0f dB');

# %%
# NOISE
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data
# STRETCH
def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate)
# SHIFT
def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)
# PITCH
def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)

# %%
# Trying different functions above
path = np.array(accent_df['path'])[303]
data, sample_rate = librosa.load(path)

# %%
plt.figure(figsize=(12, 5))
librosa.display.waveplot(y=data, sr=sample_rate)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# adding noise
x = noise(data)
plt.figure(figsize=(12,5))
librosa.display.waveplot(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Stretch
x = stretch(data)
plt.figure(figsize=(12, 5))
librosa.display.waveplot(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = shift(data)
plt.figure(figsize=(12,5))
librosa.display.waveplot(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# adding pitch
x = pitch(data, sample_rate)
plt.figure(figsize=(12, 5))
librosa.display.waveplot(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def feat_ext(data):
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
    return mfcc

def get_feat(path):
    data, sample_rate = librosa.load(path, duration=2.5, offset=0.6)
    # normal data
    res1 = feat_ext(data)
    result = np.array(res1)
    #data with noise
    noise_data = noise(data)
    res2 = feat_ext(noise_data)
    result = np.vstack((result, res2))
    #data with stretch and pitch
    new_data = stretch(data)
    data_stretch_pitch = pitch(new_data, sample_rate)
    res3 = feat_ext(data_stretch_pitch)
    result = np.vstack((result, res3))
    return result

# %%
accent_df = accent_df[:662]
accent_df
# Out:
#         labels                                              path
# 0       igbo91     /content/drive/My Drive/accentdata/igbo91.wav
# 1      igbo102    /content/drive/My Drive/accentdata/igbo102.wav
# 2    yoruba250  /content/drive/My Drive/accentdata/yoruba250.wav
# 3    yoruba361  /content/drive/My Drive/accentdata/yoruba361.wav
# 4     yoruba98   /content/drive/My Drive/accentdata/yoruba98.wav
# ..         ...                                               ...
# 657  yoruba363  /content/drive/My Drive/accentdata/yoruba363.wav
# 658  yoruba303  /content/drive/My Drive/accentdata/yoruba303.wav
# 659   yoruba34   /content/drive/My Drive/accentdata/yoruba34.wav
# 660     igbo12     /content/drive/My Drive/accentdata/igbo12.wav
# 661  yoruba218  /content/drive/My Drive/accentdata/yoruba218.wav
#
# [662 rows x 2 columns]

# %%
X, Y = [], []
for path, emotion in zip(accent_df['path'], accent_df['labels']):
    feature = get_feat(path)
    for ele in feature:
        X.append(ele)
        Y.append(emotion)

# %%
Features = pd.DataFrame(X)
Features['labels'] = Y
Features.to_csv('features.csv', index=False)
Features
# Out:
#                0           1          2          3          4          5  \
# 0    -316.384796  103.261711   3.513981  24.248024  -3.127354 -35.010544
# 1    -155.544595   25.567016  13.111573   6.416870  -1.223594 -10.929914
# 2    -369.609680   98.452370  -1.680009  23.532938 -12.880769 -37.866833
# 3    -270.087067   88.156372 -20.442574  45.649364 -14.505544   0.255894
# 4    -113.416805   30.219368   0.832551   9.645164  -1.010390  -8.203000
# ...          ...         ...        ...        ...        ...        ...
# 1981 -195.128108   71.548100  20.297831  24.220207  12.831977   8.621993
# 1982 -316.501282  108.395851   7.976588  37.857327   5.876310  12.890425
# 1983 -236.976379  137.660690 -19.353029  16.878641 -23.608492  31.057083
# 1984  -85.407388   50.532713   9.970615  -3.469896  -1.278543   7.456781
# 1985 -284.866913  131.321899 -21.238678  13.701356 -20.504547  31.706600
#
#               6          7          8          9  ...         11         12  \
# ...

# %%
Features['label'] = Features['labels'].str[0:3]

# %%
Features
# Out:
#                0           1          2          3          4          5  \
# 0    -316.384796  103.261711   3.513981  24.248024  -3.127354 -35.010544
# 1    -155.544595   25.567016  13.111573   6.416870  -1.223594 -10.929914
# 2    -369.609680   98.452370  -1.680009  23.532938 -12.880769 -37.866833
# 3    -270.087067   88.156372 -20.442574  45.649364 -14.505544   0.255894
# 4    -113.416805   30.219368   0.832551   9.645164  -1.010390  -8.203000
# ...          ...         ...        ...        ...        ...        ...
# 1981 -195.128108   71.548100  20.297831  24.220207  12.831977   8.621993
# 1982 -316.501282  108.395851   7.976588  37.857327   5.876310  12.890425
# 1983 -236.976379  137.660690 -19.353029  16.878641 -23.608492  31.057083
# 1984  -85.407388   50.532713   9.970615  -3.469896  -1.278543   7.456781
# 1985 -284.866913  131.321899 -21.238678  13.701356 -20.504547  31.706600
#
#               6          7          8          9  ...         12         13  \
# ...

# %%
Features["label"].value_counts()
# Out:
# yor    1440
# igb     408
# hau     138
# Name: label, dtype: int64
